# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
import seaborn as sns
import pandas_profiling as pp
# Out:
# <ipython-input-2-bf251cf89b4e>:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
books = pd.read_csv('/content/books.csv')

# %%
report = pp.ProfileReport(books)
display(report)

# %%
books.head()
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  rating  year        genre
# 0                  JJ Smith     4.7  2016  Non Fiction
# 1              Stephen King     4.6  2011      Fiction
# 2        Jordan B. Peterson     4.7  2018  Non Fiction
# 3             George Orwell     4.7  2017      Fiction
# 4  National Geographic Kids     4.8  2019    Childrens

# %%
books.describe()
# Out:
#            rating         year
# count  350.000000   350.000000
# mean     4.608571  2013.508571
# std      0.226941     3.284711
# min      3.300000  2009.000000
# 25%      4.500000  2010.000000
# 50%      4.600000  2013.000000
# 75%      4.800000  2016.000000
# max      4.900000  2019.000000

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    350 non-null    object
#  1   author  350 non-null    object
#  2   rating  350 non-null    float64
#  3   year    350 non-null    int64
#  4   genre   350 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 13.8+ KB

# %%
books.columns
# Out:
# Index(['name', 'author', 'rating', 'year', 'genre'], dtype='object')

# %%
books.shape
# Out:
# (350, 5)

# %%
books.dtypes
# Out:
# name       object
# author     object
# rating    float64
# year        int64
# genre      object
# dtype: object

# %%
books.describe(include=[
'object'
])
# Out:
#                                  name       author        genre
# count                             350          350          350
# unique                            350          247            3
# top     10-Day Green Smoothie Cleanse  Jeff Kinney  Non Fiction
# freq                                1           12          179

# %%
books.isnull().sum()
# Out:
# name      0
# author    0
# rating    0
# year      0
# genre     0
# dtype: int64

# %% [markdown]
# Histogram for numerical column

# %%
genre_count = books['genre'].value_counts()
genre_count
# Out:
# Non Fiction    179
# Fiction        131
# Childrens       40
# Name: genre, dtype: int64

# %%
# prompt: create a pie chart for rating

rating_counts = books['rating'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Ratings')
plt.show()
